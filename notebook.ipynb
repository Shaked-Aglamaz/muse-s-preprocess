# %%
# %gui qt

# %%
from utils import preprocess_pipeline
import matplotlib.pyplot as plt
import mne
mne.viz.set_browser_backend("qt")
# Out:
# Using qt as 2D backend.

# %%
raw_clean = preprocess_pipeline(r"C:\Users\shakeda\Downloads\26_filtered_3_channels.fif")
# Out:
# [*] Loading data...
# Opening raw data file C:\Users\shakeda\Downloads\26_filtered_3_channels.fif...
# c:\Users\shakeda\Documents\Masters\Python\muse-s-preprocess\utils.py:18: RuntimeWarning: This filename (C:\Users\shakeda\Downloads\26_filtered_3_channels.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   return mne.io.read_raw(filename, preload=True)
#     Range : 0 ... 5665403 =      0.000 ... 22661.612 secs
# Ready.
# Reading 0 ... 5665403  =      0.000 ... 22661.612 secs...
# [*] Filtering...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# ...

# %%
raw = mne.io.read_raw(r"C:\Users\shakeda\Downloads\26_filtered_3_channels.fif")
# Out:
# Opening raw data file C:\Users\shakeda\Downloads\26_filtered_3_channels.fif...
# C:\Users\shakeda\AppData\Local\Temp\ipykernel_11512\1370555777.py:1: RuntimeWarning: This filename (C:\Users\shakeda\Downloads\26_filtered_3_channels.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw(r"C:\Users\shakeda\Downloads\26_filtered_3_channels.fif")
#     Range : 0 ... 5665403 =      0.000 ... 22661.612 secs
# Ready.

# %%
raw_clean.plot()

# %%
raw.plot()
# Out:
# Channels marked as bad:
# none
# Channels marked as bad:
# none
